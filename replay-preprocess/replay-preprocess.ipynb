# %%
import sys
import enum
import json
import pandas as pd
import gc


# needs a development version of python-tetris library, since
# TetrioEngine is not included in most recent release
sys.path.append('C:\\proj\\python-tetris')
import tetris

# %%
# %run ../tetris-bag.ipynb
# %run ../tetris-field.ipynb

# %%
with open('../tetrio-dl/replays/replay.json') as f:
# with open('../tetrio-dl/replays/test-replay-200-frames-garabage-travel.ttrm') as f:
    replay = json.load(f)
    
game = replay['data'][0]
inputs = game['replays'][0]['events']

# replay['data'][0]
# tetris.impl.presets.TetrioEngine()

# %%
# class InputKey(enum.IntEnum):
#     EMPTY = 0
#     moveLeft = enum.auto()
#     moveRight = enum.auto()
#     rotateCW = enum.auto()
#     rotateCCW = enum.auto()
#     hold = enum.auto()
#     hardDrop = enum.auto()
#     softDrop = enum.auto()
    
    
class KeyState(enum.Enum):
    down = False
    up = True


class KeyStateFrame():
    def __init__(self, state=KeyState.up, frame=-1):
        self.state = state
        self.frame = frame
    
    
class KeyStates():
    def __init__(self):
        self._states = {
            'moveLeft': KeyStateFrame(),
            'moveRight': KeyStateFrame(),
            'softDrop': KeyStateFrame()
        }
    
    def keydown(self, key, frame):
        print(f'[KEYDOWN] {key} at frame {frame}')
        if self._states[key].state == KeyState.down:
            raise Exception(f'key {key} was already pressed')
        
        self._states[key].state = KeyState.down
        self._states[key].frame = frame
    

    def keyup(self, key, frame):
        if self._states[key].state == KeyState.up:
            raise Exception(f'key {key} was not pressed')
        
        # time the key was pressed
        key_downtime = frame - self._states[key].frame
        
        print(f'[KEYUP] {key} at frame {frame}, downtime {key_downtime}')
        
        self._states[key].state = KeyState.up
        
        return key_downtime

# %%
class TetrioGame():
    def __init__(self, events_df, seed, options):
        self.events_df = events_df
        self.seed = seed
        self.options = options
        self.current_event_id = 3  # start with 4th event, since first three are only initialization
                
        self.sim_game = tetris.BaseGame(tetris.impl.presets.TetrioEngine, seed=seed)
        self.key_states = KeyStates()
        
    def __str__(self):
        return str(self.events_df)
    
    def _step(self):
        current_event = self.events_df.iloc[self.current_event_id]
        current_frame = current_event['frame']
        # current_time = current_frame * (50/3)
        
        if current_event['type'] == 'keydown' or current_event['type'] == 'keyup':
            current_key = current_event['key']
            current_subframe = current_event['data']['subframe']
            
            if current_key == 'moveLeft' or current_key == 'moveRight' or current_key == 'softDrop':
                # record keyup/keydown
                method = self.key_states.keydown if current_event['type'] == 'keydown' else self.key_states.keyup
                method(current_key, current_frame + current_subframe)
            else:
                # only execute it if key is pressed
                if current_event['type'] == 'keydown':
                    self._execute_action(current_key)
            
        elif current_event['type'] == 'ige':
            print('garbage')
            pass  # garbage
        
        print(current_event)
        
        self.current_event_id += 1
    
    def _execute_action(self, key):
        match key:
            case 'moveLeft':
                self.sim_game.left()
            case 'moveRight':
                self.sim_game.right()
            case 'rotateCW':
                self.sim_game.rotate(1)
            case 'rotateCCW':
                self.sim_game.rotate(-1)
            case 'hold':
                self.sim_game.swap()
            case 'hardDrop':
                self.sim_game.hard_drop()
            case 'softDrop':
                self.sim_game.soft_drop()
    
        
        
        
class TetrioReplay():
    def __init__(self, file_path):
        self.file_path = file_path
        
        with open(file_path) as f:
            replay = json.load(f)
            
        self.games = []
        
        # for each game in the replay
        for game in replay['data']:
            # it's enough to get one seed, since both player share the seed among one game
            seed = self._get_seed(game)
            
            # for each player in this game
            for player in game['replays']:
                # load dataframe
                event_df = pd.DataFrame(player['events'])
                # make key its own column
                event_df['key'] = events_df['data'].apply(lambda d: d['key'] if 'key' in d else None)
                
                # extract player options (arr [auto repeat rate], das [delayed auto shift], sdf [soft drop factor]
                options = self._get_options(event_df)
            
                # filter out all other events beside keydown
                # event_df = event_df.loc[event_df['type'] == 'keydown']
                # event_df['data'] = event_df['data'].apply(lambda d: d['key'])
                
                tg = TetrioGame(event_df, seed, options)
                self.games.append(tg)
                
            break
          
        
        # print(len(games))
        # force garbage collection
        del replay
        # gc.collect()
        
    def _get_seed(self, game_data):
        return game_data['replays'][0]['events'][1]['data']['options']['seed']
    
    def _get_options(self, event_data):
        # ARR (Auto Repeat Rate): the speed at which tetrominoes move when holding down movement keys, measured in frames per movement
        # DAS (Delayed Auto Shift): the time between the initial keypress and the start of its automatic repeat movement, measured in frames
        # DCD (DAS Cut Delay): if not 0, any ongoing DAS movement will pause for a set amount of time after dropping/rotating a piece, measured in frames
        # SDF (Soft Drop Factor): the factor with which soft drops change the gravity speed
        return event_data.iloc[1]['data']['options']['handling']

# %%
from IPython.display import display
import ipywidgets as widgets
from IPython.display import clear_output


r = TetrioReplay('../tetrio-dl/replays/replay.json')

for i in range(20):
    r.games[0]._step()

# def clicked(arg):
#     # print("button has been clicked!")
#     clear_output()
#     r.games[0]._step()
#     print(r.games[0].sim_game)

    
# button_download = widgets.Button(description = 'Test Button')
# button_download.on_click(clicked)
# display(button_download)
# Out:
# frame                                   1
# type                              keydown
# data     {'key': 'hold', 'subframe': 0.3}
# key                                  hold
# Name: 3, dtype: object
# [KEYDOWN] softDrop at frame 3.9
# frame                                       3
# type                                  keydown
# data     {'key': 'softDrop', 'subframe': 0.9}
# key                                  softDrop
# Name: 4, dtype: object
# [KEYDOWN] moveRight at frame 4.5
# frame                                        4
# type                                   keydown
# data     {'key': 'moveRight', 'subframe': 0.5}
# key                                  moveRight
# Name: 5, dtype: object
# frame                                 6
# type                              keyup
# data     {'key': 'hold', 'subframe': 0}
# key                                hold
# Name: 6, dtype: object
# [KEYUP] moveRight at frame 12.4, downtime 7.9
# frame                                       12
# type                                     keyup
# data     {'key': 'moveRight', 'subframe': 0.4}
# key                                  moveRight
# Name: 7, dtype: object
# [KEYUP] softDrop at frame 12.6, downtime 8.7
# frame                                      12
# type                                    keyup
# data     {'key': 'softDrop', 'subframe': 0.6}
# key                                  softDrop
# Name: 8, dtype: object
# frame                                      14
# type                                  keydown
# data     {'key': 'hardDrop', 'subframe': 0.4}
# key                                  hardDrop
# Name: 9, dtype: object
# frame                                    17
# type                                  keyup
# data     {'key': 'hardDrop', 'subframe': 0}
# key                                hardDrop
# Name: 10, dtype: object
# frame                                    20
# type                                keydown
# data     {'key': 'hardDrop', 'subframe': 0}
# key                                hardDrop
# Name: 11, dtype: object
# frame                                      22
# type                                    keyup
# data     {'key': 'hardDrop', 'subframe': 0.8}
# key                                  hardDrop
# Name: 12, dtype: object
# [KEYDOWN] moveLeft at frame 24.1
# frame                                      24
# type                                  keydown
# data     {'key': 'moveLeft', 'subframe': 0.1}
# key                                  moveLeft
# Name: 13, dtype: object
# [KEYUP] moveLeft at frame 31, downtime 6.899999999999999
# frame                                    31
# type                                  keyup
# data     {'key': 'moveLeft', 'subframe': 0}
# key                                moveLeft
# Name: 14, dtype: object
# frame                                      32
# type                                  keydown
# data     {'key': 'hardDrop', 'subframe': 0.4}
# key                                  hardDrop
# Name: 15, dtype: object
# frame                                    35
# type                                  keyup
# data     {'key': 'hardDrop', 'subframe': 0}
# key                                hardDrop
# Name: 16, dtype: object
# frame                                      38
# type                                  keydown
# data     {'key': 'hardDrop', 'subframe': 0.6}
# key                                  hardDrop
# Name: 17, dtype: object
# frame                                      41
# type                                    keyup
# data     {'key': 'hardDrop', 'subframe': 0.9}
# key                                  hardDrop
# Name: 18, dtype: object
# [KEYDOWN] moveRight at frame 43.6
# frame                                       43
# type                                   keydown
# data     {'key': 'moveRight', 'subframe': 0.6}
# key                                  moveRight
# Name: 19, dtype: object
# frame                                  47
# type                              keydown
# data     {'key': 'hold', 'subframe': 0.1}
# key                                  hold
# Name: 20, dtype: object
# frame                                  51
# type                                keyup
# data     {'key': 'hold', 'subframe': 0.4}
# key                                  hold
# Name: 21, dtype: object
# [KEYUP] moveRight at frame 54.5, downtime 10.899999999999999
# frame                                       54
# type                                     keyup
# data     {'key': 'moveRight', 'subframe': 0.5}
# key                                  moveRight
# Name: 22, dtype: object

# %%
events_df = pd.DataFrame(replay['data'][0]['replays'][0]['events'])
# for d in events_df.loc[events_df['type'] == 'ige'].iterrows():
#     print(d[1]['data'])

# print('===================================================================\n' * 3)
    
# events_df = pd.DataFrame(replay['data'][0]['replays'][1]['events'])
# for d in events_df.loc[events_df['type'] == 'ige'].iterrows():
#     print(d[1]['data'])

# %%
events_df = pd.DataFrame(replay['data'][0]['replays'][0]['events'])
events_df['key'] = events_df['data'].apply(lambda d: d['key'] if 'key' in d else None)

# events_df['data'] = events_df['data'].apply(tuple)

events_df = events_df.loc[(events_df['type'] != 'keyup') | ((events_df['key'] != 'hardDrop') & (events_df['key'] != 'hold') & (events_df['key'] != 'rotateCCW') & (events_df['key'] != 'rotateCW'))]
# events_df = events_df.loc[events_df['type'] == 'keyup']

with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(events_df)

# type(events_df.iloc[3]['data']['key'])
# Out:
#      frame     type                                               data  \
# 0        0    start                                                 []
# 1        0     full  {'successful': False, 'gameoverreason': None, ...
# 2        0  targets  {'id': 'diyusi', 'frame': 0, 'type': 'targets'...
# 3        1  keydown                   {'key': 'hold', 'subframe': 0.3}
# 4        3  keydown               {'key': 'softDrop', 'subframe': 0.9}
# 5        4  keydown              {'key': 'moveRight', 'subframe': 0.5}
# 7       12    keyup              {'key': 'moveRight', 'subframe': 0.4}
# 8       12    keyup               {'key': 'softDrop', 'subframe': 0.6}
# 9       14  keydown               {'key': 'hardDrop', 'subframe': 0.4}
# 11      20  keydown                 {'key': 'hardDrop', 'subframe': 0}
# 13      24  keydown               {'key': 'moveLeft', 'subframe': 0.1}
# 14      31    keyup                 {'key': 'moveLeft', 'subframe': 0}
# 15      32  keydown               {'key': 'hardDrop', 'subframe': 0.4}
# 17      38  keydown               {'key': 'hardDrop', 'subframe': 0.6}
# 19      43  keydown              {'key': 'moveRight', 'subframe': 0.6}
# 20      47  keydown                   {'key': 'hold', 'subframe': 0.1}
# 22      54    keyup              {'key': 'moveRight', 'subframe': 0.5}
# 23      55  keydown               {'key': 'hardDrop', 'subframe': 0.9}
# 24      59  keydown                   {'key': 'hold', 'subframe': 0.1}
# 27      64  keydown               {'key': 'rotateCW', 'subframe': 0.6}
# 28      64  keydown              {'key': 'moveRight', 'subframe': 0.6}
# 29      67    keyup              {'key': 'moveRight', 'subframe': 0.8}
# 31      73  keydown                 {'key': 'hardDrop', 'subframe': 0}
# 33      78  keydown              {'key': 'moveRight', 'subframe': 0.8}
# 34      79  keydown                 {'key': 'rotateCW', 'subframe': 0}
# 36      88  keydown               {'key': 'hardDrop', 'subframe': 0.2}
# 37      92  keydown               {'key': 'moveLeft', 'subframe': 0.3}
# 39      94    keyup              {'key': 'moveRight', 'subframe': 0.6}
# 40      95    keyup               {'key': 'moveLeft', 'subframe': 0.1}
# 41      97  keydown               {'key': 'hardDrop', 'subframe': 0.5}
# 43     104  keydown                 {'key': 'hardDrop', 'subframe': 0}
# 44     104  keydown               {'key': 'moveLeft', 'subframe': 0.8}
# 45     105  keydown               {'key': 'rotateCW', 'subframe': 0.7}
# 47     111    keyup               {'key': 'moveLeft', 'subframe': 0.2}
# 49     113  keydown               {'key': 'hardDrop', 'subframe': 0.9}
# 50     114  keydown              {'key': 'rotateCCW', 'subframe': 0.6}
# 51     115  keydown               {'key': 'moveLeft', 'subframe': 0.8}
# 54     118    keyup               {'key': 'moveLeft', 'subframe': 0.9}
# 55     120  keydown               {'key': 'hardDrop', 'subframe': 0.2}
# 56     123  keydown              {'key': 'moveRight', 'subframe': 0.5}
# 58     126    keyup              {'key': 'moveRight', 'subframe': 0.8}
# 59     128  keydown               {'key': 'hardDrop', 'subframe': 0.9}
# 60     130  keydown              {'key': 'moveRight', 'subframe': 0.2}
# 62     137    keyup              {'key': 'moveRight', 'subframe': 0.7}
# 63     139  keydown               {'key': 'hardDrop', 'subframe': 0.2}
# 64     141  keydown   {'key': 'hold', 'subframe': 0.19999999999999996}
# 65     142  keydown               {'key': 'moveLeft', 'subframe': 0.8}
# 67     143  keydown               {'key': 'rotateCW', 'subframe': 0.9}
# 70     150  keydown               {'key': 'softDrop', 'subframe': 0.2}
# 71     155  keydown              {'key': 'rotateCCW', 'subframe': 0.2}
# 72     157    keyup               {'key': 'moveLeft', 'subframe': 0.6}
# 74     162  keydown              {'key': 'rotateCCW', 'subframe': 0.1}
# 76     168  keydown              {'key': 'rotateCCW', 'subframe': 0.9}
# 78     174    keyup               {'key': 'softDrop', 'subframe': 0.5}
# 79     180  keydown               {'key': 'hardDrop', 'subframe': 0.9}
# 80     181  keydown                   {'key': 'hold', 'subframe': 0.7}
# 82     185  keydown              {'key': 'moveRight', 'subframe': 0.5}
# 83     185  keydown               {'key': 'rotateCW', 'subframe': 0.9}
# 86     189    keyup              {'key': 'moveRight', 'subframe': 0.5}
# 87     191  keydown               {'key': 'hardDrop', 'subframe': 0.9}
# 88     194      ige  {'id': 0, 'frame': 194, 'type': 'ige', 'data':...
# 89     194      ige  {'id': 2, 'frame': 194, 'type': 'ige', 'data':...
# 91     196  keydown               {'key': 'rotateCW', 'subframe': 0.4}
# 92     198      ige  {'id': 3, 'frame': 194, 'type': 'ige', 'data':...
# 93     198      ige  {'id': 1, 'frame': 194, 'type': 'ige', 'data':...
# 95     200  keydown               {'key': 'hardDrop', 'subframe': 0.1}
# 96     204  keydown                {'key': 'moveRight', 'subframe': 0}
# 97     204  keydown               {'key': 'rotateCW', 'subframe': 0.6}
# 100    207    keyup                {'key': 'moveRight', 'subframe': 0}
# 101    209  keydown              {'key': 'moveRight', 'subframe': 0.5}
# 102    213    keyup                {'key': 'moveRight', 'subframe': 0}
# 103    213  keydown               {'key': 'hardDrop', 'subframe': 0.5}
# 104    215  keydown                   {'key': 'hold', 'subframe': 0.1}
# 106    218  keydown               {'key': 'moveLeft', 'subframe': 0.1}
# 108    220    keyup               {'key': 'moveLeft', 'subframe': 0.3}
# 109    223  keydown               {'key': 'moveLeft', 'subframe': 0.8}
# 110    226    keyup               {'key': 'moveLeft', 'subframe': 0.2}
# 111    227  keydown               {'key': 'hardDrop', 'subframe': 0.8}
# 112    229  keydown                {'key': 'rotateCCW', 'subframe': 0}
# 113    230  keydown              {'key': 'moveRight', 'subframe': 0.9}
# 116    239  keydown               {'key': 'softDrop', 'subframe': 0.8}
# 117    245  keydown              {'key': 'rotateCCW', 'subframe': 0.4}
# 118    245    keyup              {'key': 'moveRight', 'subframe': 0.7}
# 119    246    keyup               {'key': 'softDrop', 'subframe': 0.7}
# 120    248  keydown               {'key': 'hardDrop', 'subframe': 0.7}
# 122    251  keydown               {'key': 'moveLeft', 'subframe': 0.5}
# 124    253  keydown               {'key': 'rotateCW', 'subframe': 0.9}
# 126    261  keydown                 {'key': 'softDrop', 'subframe': 0}
# 127    265  keydown              {'key': 'rotateCCW', 'subframe': 0.2}
# 128    267    keyup               {'key': 'moveLeft', 'subframe': 0.7}
# 130    272    keyup                 {'key': 'softDrop', 'subframe': 0}
# 131    272  keydown              {'key': 'rotateCCW', 'subframe': 0.1}
# 133    279  keydown                 {'key': 'hardDrop', 'subframe': 0}
# 135    287  keydown               {'key': 'hardDrop', 'subframe': 0.1}
# 137    302  keydown                   {'key': 'hold', 'subframe': 0.7}
# 139    309  keydown               {'key': 'hardDrop', 'subframe': 0.9}
# 140    313  keydown              {'key': 'moveRight', 'subframe': 0.7}
# 142    319    keyup              {'key': 'moveRight', 'subframe': 0.9}
# 143    321  keydown               {'key': 'hardDrop', 'subframe': 0.5}
# 145    324  keydown               {'key': 'moveLeft', 'subframe': 0.9}
# 146    328    keyup               {'key': 'moveLeft', 'subframe': 0.9}
# 147    333  keydown               {'key': 'moveLeft', 'subframe': 0.6}
# 148    336    keyup                 {'key': 'moveLeft', 'subframe': 0}
# 149    341  keydown              {'key': 'moveRight', 'subframe': 0.2}
# 150    345      ige  {'id': 4, 'frame': 345, 'type': 'ige', 'data':...
# 151    350      ige  {'id': 5, 'frame': 345, 'type': 'ige', 'data':...
# 152    350    keyup              {'key': 'moveRight', 'subframe': 0.5}
# 153    352  keydown               {'key': 'hardDrop', 'subframe': 0.8}
# 154    354  keydown              {'key': 'rotateCCW', 'subframe': 0.5}
# 155    355  keydown               {'key': 'moveLeft', 'subframe': 0.8}
# 158    361  keydown               {'key': 'softDrop', 'subframe': 0.3}
# 159    364  keydown              {'key': 'rotateCCW', 'subframe': 0.5}
# 160    368    keyup               {'key': 'softDrop', 'subframe': 0.4}
# 162    369  keydown               {'key': 'hardDrop', 'subframe': 0.5}
# 163    373  keydown                   {'key': 'hold', 'subframe': 0.4}
# 166    384  keydown                {'key': 'rotateCCW', 'subframe': 0}
# 168    394  keydown               {'key': 'hardDrop', 'subframe': 0.8}
# 169    398  keydown                {'key': 'rotateCCW', 'subframe': 0}
# 172    403  keydown              {'key': 'moveRight', 'subframe': 0.5}
# 173    405    keyup               {'key': 'moveLeft', 'subframe': 0.1}
# 174    405      ige  {'id': 6, 'frame': 405, 'type': 'ige', 'data':...
# 175    406    keyup              {'key': 'moveRight', 'subframe': 0.7}
# 176    408      ige  {'id': 7, 'frame': 405, 'type': 'ige', 'data':...
# 177    408  keydown               {'key': 'hardDrop', 'subframe': 0.9}
# 178    410  keydown              {'key': 'rotateCCW', 'subframe': 0.4}
# 179    411  keydown               {'key': 'moveLeft', 'subframe': 0.5}
# 182    422    keyup                 {'key': 'moveLeft', 'subframe': 0}
# 183    422  keydown               {'key': 'hardDrop', 'subframe': 0.7}
# 184    427  keydown              {'key': 'moveRight', 'subframe': 0.5}
# 186    433  keydown               {'key': 'moveLeft', 'subframe': 0.6}
# 187    434    keyup              {'key': 'moveRight', 'subframe': 0.7}
# 188    435  keydown               {'key': 'hardDrop', 'subframe': 0.1}
# 189    436  keydown              {'key': 'rotateCCW', 'subframe': 0.4}
# 192    444    keyup               {'key': 'moveLeft', 'subframe': 0.1}
# 193    446  keydown               {'key': 'hardDrop', 'subframe': 0.4}
# 194    446      end  {'reason': 'topout', 'export': {'successful': ...
#
#            key
# 0         None
# 1         None
# 2         None
# 3         hold
# 4     softDrop
# 5    moveRight
# 7    moveRight
# 8     softDrop
# 9     hardDrop
# 11    hardDrop
# 13    moveLeft
# 14    moveLeft
# 15    hardDrop
# 17    hardDrop
# 19   moveRight
# 20        hold
# 22   moveRight
# 23    hardDrop
# 24        hold
# 27    rotateCW
# 28   moveRight
# 29   moveRight
# 31    hardDrop
# 33   moveRight
# 34    rotateCW
# 36    hardDrop
# 37    moveLeft
# 39   moveRight
# 40    moveLeft
# 41    hardDrop
# 43    hardDrop
# 44    moveLeft
# 45    rotateCW
# 47    moveLeft
# 49    hardDrop
# 50   rotateCCW
# 51    moveLeft
# 54    moveLeft
# 55    hardDrop
# 56   moveRight
# 58   moveRight
# 59    hardDrop
# 60   moveRight
# 62   moveRight
# 63    hardDrop
# 64        hold
# 65    moveLeft
# 67    rotateCW
# 70    softDrop
# 71   rotateCCW
# 72    moveLeft
# 74   rotateCCW
# 76   rotateCCW
# 78    softDrop
# 79    hardDrop
# 80        hold
# 82   moveRight
# 83    rotateCW
# 86   moveRight
# 87    hardDrop
# 88        None
# 89        None
# 91    rotateCW
# 92        None
# 93        None
# 95    hardDrop
# 96   moveRight
# 97    rotateCW
# 100  moveRight
# 101  moveRight
# 102  moveRight
# 103   hardDrop
# 104       hold
# 106   moveLeft
# 108   moveLeft
# 109   moveLeft
# 110   moveLeft
# 111   hardDrop
# 112  rotateCCW
# 113  moveRight
# 116   softDrop
# 117  rotateCCW
# 118  moveRight
# 119   softDrop
# 120   hardDrop
# 122   moveLeft
# 124   rotateCW
# 126   softDrop
# 127  rotateCCW
# 128   moveLeft
# 130   softDrop
# 131  rotateCCW
# 133   hardDrop
# 135   hardDrop
# 137       hold
# 139   hardDrop
# 140  moveRight
# 142  moveRight
# 143   hardDrop
# 145   moveLeft
# 146   moveLeft
# 147   moveLeft
# 148   moveLeft
# 149  moveRight
# 150       None
# 151       None
# 152  moveRight
# 153   hardDrop
# 154  rotateCCW
# 155   moveLeft
# 158   softDrop
# 159  rotateCCW
# 160   softDrop
# 162   hardDrop
# 163       hold
# 166  rotateCCW
# 168   hardDrop
# 169  rotateCCW
# 172  moveRight
# 173   moveLeft
# 174       None
# 175  moveRight
# 176       None
# 177   hardDrop
# 178  rotateCCW
# 179   moveLeft
# 182   moveLeft
# 183   hardDrop
# 184  moveRight
# 186   moveLeft
# 187  moveRight
# 188   hardDrop
# 189  rotateCCW
# 192   moveLeft
# 193   hardDrop
# 194       None

# %%
'
